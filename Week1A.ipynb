# %% [markdown]
# <a href="https://colab.research.google.com/github/marcusbutta/CSC221_mbutt007/blob/main/Week1A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
while 0 == 0:
  print("amogus")
# Out:
# Streaming output truncated to the last 5000 lines.
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# amogus
# ...
